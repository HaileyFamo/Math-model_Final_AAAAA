# %%
"""
    表单1堆叠柱状图
"""
import matplotlib.pyplot as plt

# 定义新的颜色
weathered_color = 'coral'
not_weathered_color = 'skyblue'

# 纹饰图
name_list = list(no_weather_info['纹饰'].keys())
weathered_values = list(weather_info['纹饰'].values())
not_weathered_values = list(no_weather_info['纹饰'].values())

plt.figure(figsize=(12, 10))  # 设置图片尺寸

# 堆叠条形图
plt.subplot(3, 1, 1)
plt.barh(range(len(name_list)), weathered_values, label='风化', color=weathered_color)
plt.barh(range(len(name_list)), not_weathered_values, left=weathered_values, label='未风化', color=not_weathered_color)
plt.yticks(range(len(name_list)), name_list)
plt.xlabel('数量')
plt.ylabel('纹饰')
plt.title('风化程度与纹饰关系图')
plt.legend()

# 类型图
name_list = list(no_weather_info['类型'].keys())
weathered_values = list(weather_info['类型'].values())
not_weathered_values = list(no_weather_info['类型'].values())

plt.subplot(3, 1, 2)
plt.barh(range(len(name_list)), weathered_values, label='风化', color=weathered_color)
plt.barh(range(len(name_list)), not_weathered_values, left=weathered_values, label='未风化', color=not_weathered_color)
plt.yticks(range(len(name_list)), name_list)
plt.xlabel('数量')
plt.ylabel('类型')
plt.title('风化程度与类型关系图')
plt.legend()

# 颜色图
name_list = list(no_weather_info['颜色'].keys())
weathered_values = list(weather_info['颜色'].values())
not_weathered_values = list(no_weather_info['颜色'].values())

plt.subplot(3, 1, 3)
plt.barh(range(len(name_list)), weathered_values, label='风化', color=weathered_color)
plt.barh(range(len(name_list)), not_weathered_values, left=weathered_values, label='未风化', color=not_weathered_color)
plt.yticks(range(len(name_list)), name_list)
plt.xlabel('数量')
plt.ylabel('颜色')
plt.title('风化程度与颜色关系图')
plt.legend()

plt.tight_layout()
plt.savefig(r'D:\我的文档\大二下\数学建模\2022CUMCM-C\过程性文件\picture\第一问图像\风化程度与类型、纹饰、颜色关系图\修改图.png')

plt.show()  # 显示图像
